# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Australia Batting Data set

# %%
df1=pd.read_csv(r"C:\Users\Gayan\Downloads\AUS batting.csv")

# %%
df1.head()
# Out:
#         Player  Mat  Inns  NO  Runs  HS    Ave   BF     SR  100  50  0  4s  6s
# 0  CT Bancroft    2     4   0    44  16  11.00  162  27.16    0   0  0   6   0
# 1     JA Burns    7    12   1   319  97  29.00  683  46.70    0   3  2  33   4
# 2   PJ Cummins   14    20   3   180  28  10.58  568  31.69    0   0  5  18   1
# 3      C Green    4     7   0   236  84  33.71  580  40.68    0   1  1  23   4
# 4    MS Harris    4     8   0   101  38  12.62  226  44.69    0   0  0  17   0

# %% [markdown]
# # Remove Unnecessary Columns (Bat)

# %%
df2=df1.drop(columns=['NO','BF','0','4s','6s'])
df2.head()
# Out:
#         Player  Mat  Inns  Runs  HS    Ave     SR  100  50
# 0  CT Bancroft    2     4    44  16  11.00  27.16    0   0
# 1     JA Burns    7    12   319  97  29.00  46.70    0   3
# 2   PJ Cummins   14    20   180  28  10.58  31.69    0   0
# 3      C Green    4     7   236  84  33.71  40.68    0   1
# 4    MS Harris    4     8   101  38  12.62  44.69    0   0

# %% [markdown]
# # Import Australia Bowling Data Set

# %%
df3=pd.read_csv(r"C:\Users\Gayan\Downloads\AUS bowling.csv")
df3.head()
# Out:
#         Player  Mat Inns  Overs Mdns  Runs Wkts   BBI   BBM    Ave  Econ  \
# 0  CT Bancroft    2    -      -    -     -    -     -     -      -     -
# 1     JA Burns    7    -      -    -     -    -     -     -      -     -
# 2   PJ Cummins   14   28  555.3  158  1472   70  5/28  7/69  21.02  2.64
# 3      C Green    4    6   44.0    7   118    0     -     -      -  2.68
# 4    MS Harris    4    -      -    -     -    -     -     -      -     -
#
#      SR  5 10  Ct  St
# 0     -  -  -   5   0
# 1     -  -  -   5   0
# 2  47.6  1  0   7   0
# 3     -  0  0   5   0
# 4     -  -  -   0   0

# %% [markdown]
# # Remove Unnecessary Columns(Ball)

# %%
df4=df3.drop(columns=['Mat','Inns','Overs','Mdns','Runs','Ct','St'])
df4.head()
# Out:
#         Player Wkts   BBI   BBM    Ave  Econ    SR  5 10
# 0  CT Bancroft    -     -     -      -     -     -  -  -
# 1     JA Burns    -     -     -      -     -     -  -  -
# 2   PJ Cummins   70  5/28  7/69  21.02  2.64  47.6  1  0
# 3      C Green    0     -     -      -  2.68     -  0  0
# 4    MS Harris    -     -     -      -     -     -  -  -

# %% [markdown]
# # Joing batting and Bowling data sets

# %%
df5=pd.merge(df2, df4, on='Player')
df5
# Out:
#            Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts   BBI  \
# 0     CT Bancroft    2     4    44   16  11.00  27.16    0   0    -     -
# 1        JA Burns    7    12   319   97  29.00  46.70    0   3    -     -
# 2      PJ Cummins   14    20   180   28  10.58  31.69    0   0   70  5/28
# 3         C Green    4     7   236   84  33.71  40.68    0   1    0     -
# 4       MS Harris    4     8   101   38  12.62  44.69    0   0    -     -
# 5    JR Hazlewood   11    13    57   11   9.50  57.00    0   0   48   5/8
# 6         TM Head   11    17   490  114  30.62  47.89    1   2    0     -
# 7      UT Khawaja    3     6   122   40  20.33  64.89    0   0    -     -
# 8   M Labuschagne   13    23  1675  215  72.82  55.85    5   9    3   1/9
# 9         NM Lyon   14    18   178   26  13.69  64.72    0   0   56  6/49
# 10       MR Marsh    1     2    41   24  20.50  36.93    0   0    7  5/46
# 11       TD Paine   14    22   550   79  28.94  51.06    0   4    -     -
# ...

# %% [markdown]
# # Create column with country

# %%
df_AUS=df5.assign(Country = ['Australia']*19)
df_AUS
# Out:
#            Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts   BBI  \
# 0     CT Bancroft    2     4    44   16  11.00  27.16    0   0    -     -
# 1        JA Burns    7    12   319   97  29.00  46.70    0   3    -     -
# 2      PJ Cummins   14    20   180   28  10.58  31.69    0   0   70  5/28
# 3         C Green    4     7   236   84  33.71  40.68    0   1    0     -
# 4       MS Harris    4     8   101   38  12.62  44.69    0   0    -     -
# 5    JR Hazlewood   11    13    57   11   9.50  57.00    0   0   48   5/8
# 6         TM Head   11    17   490  114  30.62  47.89    1   2    0     -
# 7      UT Khawaja    3     6   122   40  20.33  64.89    0   0    -     -
# 8   M Labuschagne   13    23  1675  215  72.82  55.85    5   9    3   1/9
# 9         NM Lyon   14    18   178   26  13.69  64.72    0   0   56  6/49
# 10       MR Marsh    1     2    41   24  20.50  36.93    0   0    7  5/46
# 11       TD Paine   14    22   550   79  28.94  51.06    0   4    -     -
# ...

# %% [markdown]
# # Bangaladesh

# %%
df6=pd.read_csv(r"C:\Users\Gayan\Downloads\Bangladesh batting.csv")
df7=df6.drop(columns=['Span','NO','BF','0','4s','6s'])
df7
# Out:
#                    Player  Mat  Inns  Runs   HS    Ave     SR  100  50
# 0               Abu Jayed    6    10    17   7*   3.40  23.28    0   0
# 1         Al-Amin Hossain    1     2    22   21  22.00  91.66    0   0
# 2          Ebadat Hossain    4     6     4    2   1.00  14.28    0   0
# 3             Imrul Kayes    2     4    21    6   5.25  34.42    0   0
# 4               Liton Das    7    12   417   71  37.90  61.96    0   3
# 5             Mahmudullah    3     6    95  39*  19.00  53.97    0   0
# 6      Mehidy Hasan Miraz    6    11   317  103  28.81  52.83    1   1
# 7         Mohammad Mithun    4     8   125   63  15.62  38.34    0   1
# 8           Mominul Haque    7    14   534  127  41.07  44.76    2   0
# 9         Mushfiqur Rahim    6    11   453   74  45.30  51.01    0   4
# 10      Mustafizur Rahman    1     1     3   3*      -  27.27    0   0
# 11           Nayeem Hasan    3     5    58   24  14.50  59.18    0   0
# ...

# %%
df8=pd.read_csv(r"C:\Users\Gayan\Downloads\Bangladesh bowling.csv")
df9=df8.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])
df9
# Out:
#                    Player Wkts    BBI    BBM    Ave  Econ     SR  5 10
# 0               Abu Jayed   15   4/98  6/130  36.40  3.54   61.6  0  0
# 1         Al-Amin Hossain    3   3/85   3/85  28.33  3.75   45.3  0  0
# 2          Ebadat Hossain    6   3/91   3/91  67.00  4.10   98.0  0  0
# 3             Imrul Kayes    -      -      -      -     -      -  -  -
# 4               Liton Das    -      -      -      -     -      -  -  -
# 5             Mahmudullah    0      -      -      -  6.00      -  0  0
# 6      Mehidy Hasan Miraz   15   4/58  8/171  48.73  3.11   94.0  0  0
# 7         Mohammad Mithun    -      -      -      -     -      -  -  -
# 8           Mominul Haque    0      -      -      -  4.50      -  0  0
# 9         Mushfiqur Rahim    -      -      -      -     -      -  -  -
# 10      Mustafizur Rahman    2   2/46  2/117  58.50  4.17   84.0  0  0
# 11           Nayeem Hasan    6   3/34  3/108  44.50  2.95   90.3  0  0
# ...

# %%
df10=pd.merge(df7, df9, on='Player')
df10
# Out:
#                    Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts  \
# 0               Abu Jayed    6    10    17   7*   3.40  23.28    0   0   15
# 1         Al-Amin Hossain    1     2    22   21  22.00  91.66    0   0    3
# 2          Ebadat Hossain    4     6     4    2   1.00  14.28    0   0    6
# 3             Imrul Kayes    2     4    21    6   5.25  34.42    0   0    -
# 4               Liton Das    7    12   417   71  37.90  61.96    0   3    -
# 5             Mahmudullah    3     6    95  39*  19.00  53.97    0   0    0
# 6      Mehidy Hasan Miraz    6    11   317  103  28.81  52.83    1   1   15
# 7         Mohammad Mithun    4     8   125   63  15.62  38.34    0   1    -
# 8           Mominul Haque    7    14   534  127  41.07  44.76    2   0    0
# 9         Mushfiqur Rahim    6    11   453   74  45.30  51.01    0   4    -
# 10      Mustafizur Rahman    1     1     3   3*      -  27.27    0   0    2
# ...

# %%
df_BAN=df10.assign(Country = ['Bangaladesh']*22)
df_BAN
# Out:
#                    Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts  \
# 0               Abu Jayed    6    10    17   7*   3.40  23.28    0   0   15
# 1         Al-Amin Hossain    1     2    22   21  22.00  91.66    0   0    3
# 2          Ebadat Hossain    4     6     4    2   1.00  14.28    0   0    6
# 3             Imrul Kayes    2     4    21    6   5.25  34.42    0   0    -
# 4               Liton Das    7    12   417   71  37.90  61.96    0   3    -
# 5             Mahmudullah    3     6    95  39*  19.00  53.97    0   0    0
# 6      Mehidy Hasan Miraz    6    11   317  103  28.81  52.83    1   1   15
# 7         Mohammad Mithun    4     8   125   63  15.62  38.34    0   1    -
# 8           Mominul Haque    7    14   534  127  41.07  44.76    2   0    0
# 9         Mushfiqur Rahim    6    11   453   74  45.30  51.01    0   4    -
# 10      Mustafizur Rahman    1     1     3   3*      -  27.27    0   0    2
# ...

# %% [markdown]
# # England

# %%
df11=pd.read_csv(r"C:\Users\Gayan\Downloads\England batting.csv")
df12=df11.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df13=pd.read_csv(r"C:\Users\Gayan\Downloads\England bowling.csv")
df14=df13.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df15=pd.merge(df12, df14, on='Player')
df15
# Out:
#          Player  Mat  Inns  Runs    HS  Ave_x    SR_x  100  50 Wkts    BBI  \
# 0        MM Ali    2     4    53    43  13.25   65.43    0   0   11   4/98
# 1   JM Anderson   13    18    60    11   6.66   38.46    0   0   43   6/40
# 2     JC Archer   11    17   113    23   6.64   46.88    0   0   40   6/45
# 3   JM Bairstow   11    22   450    52  22.50   48.64    0   1    -      -
# 4       DM Bess   12    16   208    34  18.90   42.02    0   0   33   5/30
# 5     SCJ Broad   18    27   270    62  16.87   72.58    0   1   70   6/31
# 6      RJ Burns   15    27   813   133  30.11   44.96    1   5    -      -
# 7    JC Buttler   19    33   980   152  31.61   52.65    1   4    -      -
# 8     Z Crawley   12    21   715   267  34.04   54.33    1   4    -      -
# 9     SM Curran   10    14   251    44  19.30   72.54    0   0   20   4/58
# 10     JL Denly   10    19   569    94  29.94   38.91    0   4    2   2/42
# ...

# %%
df_ENG=df15.assign(Country = ['England']*24)
df_ENG
# Out:
#          Player  Mat  Inns  Runs    HS  Ave_x    SR_x  100  50 Wkts    BBI  \
# 0        MM Ali    2     4    53    43  13.25   65.43    0   0   11   4/98
# 1   JM Anderson   13    18    60    11   6.66   38.46    0   0   43   6/40
# 2     JC Archer   11    17   113    23   6.64   46.88    0   0   40   6/45
# 3   JM Bairstow   11    22   450    52  22.50   48.64    0   1    -      -
# 4       DM Bess   12    16   208    34  18.90   42.02    0   0   33   5/30
# 5     SCJ Broad   18    27   270    62  16.87   72.58    0   1   70   6/31
# 6      RJ Burns   15    27   813   133  30.11   44.96    1   5    -      -
# 7    JC Buttler   19    33   980   152  31.61   52.65    1   4    -      -
# 8     Z Crawley   12    21   715   267  34.04   54.33    1   4    -      -
# 9     SM Curran   10    14   251    44  19.30   72.54    0   0   20   4/58
# 10     JL Denly   10    19   569    94  29.94   38.91    0   4    2   2/42
# ...

# %% [markdown]
# # India

# %%
df16=pd.read_csv(r"C:\Users\Gayan\Downloads\India batting.csv")
df17=df16.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df18=pd.read_csv(r"C:\Users\Gayan\Downloads\India bowling.csv")
df19=df18.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df20=pd.merge(df17, df19, on='Player')
df20
# Out:
#                Player  Mat  Inns  Runs    HS  Ave_x    SR_x  100  50 Wkts  \
# 0          MA Agarwal   12    20   857   243  42.85   55.07    3   2    -
# 1            R Ashwin   14    18   324   106  20.25   47.23    1   0   71
# 2           JJ Bumrah   11    16    57    28   5.18   44.53    0   0   43
# 3           RA Jadeja   12    16   556    91  50.54   54.72    0   6   29
# 4             V Kohli   16    25   934  254*  40.60   54.14    2   5    0
# 5       Kuldeep Yadav    1     2     3     3   1.50   12.50    0   0    2
# 6      Mohammed Shami   12    13    95    21  11.87   94.05    0   0   44
# 7      Mohammed Siraj    6     7    46   16*  11.50   82.14    0   0   19
# 8            S Nadeem    2     3     1    1*   0.50    3.33    0   0    8
# 9         T Natarajan    1     1     1    1*      -   11.11    0   0    3
# 10            RR Pant   13    21   732   101  38.52   67.34    1   4    -
# 11           AR Patel    3     4    55    43  13.75   41.98    0   0   27
# ...

# %%
df_IND=df20.assign(Country = ['India']*25)
df_IND
# Out:
#                Player  Mat  Inns  Runs    HS  Ave_x    SR_x  100  50 Wkts  \
# 0          MA Agarwal   12    20   857   243  42.85   55.07    3   2    -
# 1            R Ashwin   14    18   324   106  20.25   47.23    1   0   71
# 2           JJ Bumrah   11    16    57    28   5.18   44.53    0   0   43
# 3           RA Jadeja   12    16   556    91  50.54   54.72    0   6   29
# 4             V Kohli   16    25   934  254*  40.60   54.14    2   5    0
# 5       Kuldeep Yadav    1     2     3     3   1.50   12.50    0   0    2
# 6      Mohammed Shami   12    13    95    21  11.87   94.05    0   0   44
# 7      Mohammed Siraj    6     7    46   16*  11.50   82.14    0   0   19
# 8            S Nadeem    2     3     1    1*   0.50    3.33    0   0    8
# 9         T Natarajan    1     1     1    1*      -   11.11    0   0    3
# 10            RR Pant   13    21   732   101  38.52   67.34    1   4    -
# 11           AR Patel    3     4    55    43  13.75   41.98    0   0   27
# ...

# %% [markdown]
# # New Zeland

# %%
df21=pd.read_csv(r"C:\Users\Gayan\Downloads\NZ batting.csv")
df22=df21.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df23=pd.read_csv(r"C:\Users\Gayan\Downloads\NZ bowling.csv")
df24=df23.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df25=pd.merge(df22, df24, on='Player')
df25
# Out:
#              Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0          TD Astle    1     2    42   25*  42.00  51.85    0   0    3  2/111
# 1       TA Blundell    8    13   402   121  33.50  45.06    1   2    0      -
# 2          TA Boult   10     8   112    38  22.40  98.24    0   0   39   4/28
# 3         DP Conway    1     2    73    54  36.50  36.50    0   1    -      -
# 4   C de Grandhomme    7    10   313    83  31.30  69.86    0   2   11   3/78
# 5       LH Ferguson    1     2     1    1*      -  11.11    0   0    0      -
# 6          MJ Henry    2     1     3     3   3.00  20.00    0   0    3   1/54
# 7       KA Jamieson    7     7   247   51*  49.40  73.51    0   1   43   6/48
# 8        TWM Latham   12    20   719   154  37.84  44.90    1   5    -      -
# 9       DJ Mitchell    3     3   153  102*  76.50  70.50    1   0    1    1/7
# 10      HM Nicholls   11    16   592   174  39.46  49.70    2   1    -      -
# ...

# %%
df_NZ=df25.assign(Country = ['New Zeland']*22)
df_NZ
# Out:
#              Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0          TD Astle    1     2    42   25*  42.00  51.85    0   0    3  2/111
# 1       TA Blundell    8    13   402   121  33.50  45.06    1   2    0      -
# 2          TA Boult   10     8   112    38  22.40  98.24    0   0   39   4/28
# 3         DP Conway    1     2    73    54  36.50  36.50    0   1    -      -
# 4   C de Grandhomme    7    10   313    83  31.30  69.86    0   2   11   3/78
# 5       LH Ferguson    1     2     1    1*      -  11.11    0   0    0      -
# 6          MJ Henry    2     1     3     3   3.00  20.00    0   0    3   1/54
# 7       KA Jamieson    7     7   247   51*  49.40  73.51    0   1   43   6/48
# 8        TWM Latham   12    20   719   154  37.84  44.90    1   5    -      -
# 9       DJ Mitchell    3     3   153  102*  76.50  70.50    1   0    1    1/7
# 10      HM Nicholls   11    16   592   174  39.46  49.70    2   1    -      -
# ...

# %% [markdown]
# # Pakistan

# %%
df26=pd.read_csv(r"C:\Users\Gayan\Downloads\Pakistan batting.csv")
df27=df26.drop(columns=['NO','BF','0','4s','6s'])

# %%
df28=pd.read_csv(r"C:\Users\Gayan\Downloads\Pakistan bowling.csv")
df29=df28.drop(columns=['Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df30=pd.merge(df27, df29, on='Player')
df30
# Out:
#                  Player  Mat Inns Runs    HS  Ave_x   SR_x 100 50 Wkts    BBI  \
# 0              Abid Ali   10   17  569   174  35.56  44.62   2  1    -      -
# 1           Asad Shafiq    8   11  337    76  30.63  50.60   0  4    1   1/24
# 2             Azhar Ali   12   21  748  141*  39.36  44.33   2  2    0      -
# 3            Babar Azam   10   17  932   143  66.57  64.14   4  5    -      -
# 4         Faheem Ashraf    4    7  357    91  59.50  58.71   0  3    4  2/106
# 5            Fawad Alam    6   11  320   109  35.55  36.07   2  0    2   2/46
# 6          Haris Sohail    6    8  121    75  15.12  44.32   0  1    6   2/11
# 7             Hasan Ali    2    3   34    21  11.33  42.50   0  0   12   5/54
# 8        Iftikhar Ahmed    2    4   44    27  11.00  37.28   0  0    0      -
# 9           Imam-ul-Haq    1    2    2     2   1.00   8.00   0  0    -      -
# 10           Imran Butt    2    4   36    15   9.00  34.61   0  0    -      -
# ...

# %%
df_PAK=df30.assign(Country = ['pakistan']*23)
df_PAK
# Out:
#                  Player  Mat Inns Runs    HS  Ave_x   SR_x 100 50 Wkts    BBI  \
# 0              Abid Ali   10   17  569   174  35.56  44.62   2  1    -      -
# 1           Asad Shafiq    8   11  337    76  30.63  50.60   0  4    1   1/24
# 2             Azhar Ali   12   21  748  141*  39.36  44.33   2  2    0      -
# 3            Babar Azam   10   17  932   143  66.57  64.14   4  5    -      -
# 4         Faheem Ashraf    4    7  357    91  59.50  58.71   0  3    4  2/106
# 5            Fawad Alam    6   11  320   109  35.55  36.07   2  0    2   2/46
# 6          Haris Sohail    6    8  121    75  15.12  44.32   0  1    6   2/11
# 7             Hasan Ali    2    3   34    21  11.33  42.50   0  0   12   5/54
# 8        Iftikhar Ahmed    2    4   44    27  11.00  37.28   0  0    0      -
# 9           Imam-ul-Haq    1    2    2     2   1.00   8.00   0  0    -      -
# 10           Imran Butt    2    4   36    15   9.00  34.61   0  0    -      -
# ...

# %% [markdown]
# # South Africa

# %%
df31=pd.read_csv(r"C:\Users\Gayan\Downloads\South Africa batting.csv")
df32=df31.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df33=pd.read_csv(r"C:\Users\Gayan\Downloads\South Africa bowling.csv")
df34=df33.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df35=pd.merge(df32, df34, on='Player')
df35
# Out:
#                Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts  \
# 0            T Bavuma    8    14   381    71  29.30  46.69    0   2    -
# 1         TB de Bruyn    3     5    82    30  16.40  46.85    0   0    -
# 2           Q de Kock   13    23   847  141*  38.50  66.12    2   5    -
# 3        F du Plessis   11    20   555   199  27.75  48.17    1   2    -
# 4             D Elgar   13    24   935   160  42.50  54.45    2   4    1
# 5        BE Hendricks    1     2     9    5*   9.00  50.00    0   0    6
# 6           H Klaasen    1     2    11     6   5.50  32.35    0   0    -
# 7            GF Linde    3     6   135    37  22.50  52.94    0   0    9
# 8          KA Maharaj   11    19   293    73  15.42  46.65    0   3   35
# 9            PJ Malan    3     6   156    84  26.00  29.43    0   1    0
# 10         AK Markram    9    16   466   108  31.06  48.84    1   3    0
# 11         PWA Mulder    5     7   129    36  18.42  42.15    0   0   13
# ...

# %%
df_SF=df35.assign(Country = ['South Africa']*25)
df_SF
# Out:
#                Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts  \
# 0            T Bavuma    8    14   381    71  29.30  46.69    0   2    -
# 1         TB de Bruyn    3     5    82    30  16.40  46.85    0   0    -
# 2           Q de Kock   13    23   847  141*  38.50  66.12    2   5    -
# 3        F du Plessis   11    20   555   199  27.75  48.17    1   2    -
# 4             D Elgar   13    24   935   160  42.50  54.45    2   4    1
# 5        BE Hendricks    1     2     9    5*   9.00  50.00    0   0    6
# 6           H Klaasen    1     2    11     6   5.50  32.35    0   0    -
# 7            GF Linde    3     6   135    37  22.50  52.94    0   0    9
# 8          KA Maharaj   11    19   293    73  15.42  46.65    0   3   35
# 9            PJ Malan    3     6   156    84  26.00  29.43    0   1    0
# 10         AK Markram    9    16   466   108  31.06  48.84    1   3    0
# 11         PWA Mulder    5     7   129    36  18.42  42.15    0   0   13
# ...

# %% [markdown]
# # Sri Lanka

# %%
df36=pd.read_csv(r"C:\Users\Gayan\Downloads\SL batting.csv")
df37=df36.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df38=pd.read_csv(r"C:\Users\Gayan\Downloads\SL bowling.csv")
df39=df38.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df40=pd.merge(df37, df39, on='Player')
df40
# Out:
#              Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0         M Bhanuka    1     2     6    5   3.00  35.29    0   0    -      -
# 1      PVD Chameera    3     5    32   22   6.40  39.50    0   0    8   3/69
# 2      LD Chandimal    7    13   359   85  29.91  44.21    0   3    -      -
# 3       A Dananjaya    1     1     0    0   0.00   0.00    0   0    6   5/80
# 4       DM de Silva    9    14   653  166  59.36  57.68    3   2    6   3/25
# 5      PWH de Silva    4     7   196   59  28.00  86.34    0   1    4  4/171
# 6       N Dickwella   12    20   753   96  39.63  59.15    0   6    -      -
# 7     L Embuldeniya    7    12    88   40   8.00  44.22    0   0   30  7/137
# 8       AM Fernando    3     6     4    4   1.33  12.50    0   0    4   2/44
# 9      BOP Fernando    7    12   430  102  39.09  46.63    1   3    0      -
# 10     MVT Fernando    8    10     9   5*   2.25  11.11    0   0   19  5/101
# ...

# %%
df_SL=df40.assign(Country = ['Sri Lanka']*24)
df_SL
# Out:
#              Player  Mat  Inns  Runs   HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0         M Bhanuka    1     2     6    5   3.00  35.29    0   0    -      -
# 1      PVD Chameera    3     5    32   22   6.40  39.50    0   0    8   3/69
# 2      LD Chandimal    7    13   359   85  29.91  44.21    0   3    -      -
# 3       A Dananjaya    1     1     0    0   0.00   0.00    0   0    6   5/80
# 4       DM de Silva    9    14   653  166  59.36  57.68    3   2    6   3/25
# 5      PWH de Silva    4     7   196   59  28.00  86.34    0   1    4  4/171
# 6       N Dickwella   12    20   753   96  39.63  59.15    0   6    -      -
# 7     L Embuldeniya    7    12    88   40   8.00  44.22    0   0   30  7/137
# 8       AM Fernando    3     6     4    4   1.33  12.50    0   0    4   2/44
# 9      BOP Fernando    7    12   430  102  39.09  46.63    1   3    0      -
# 10     MVT Fernando    8    10     9   5*   2.25  11.11    0   0   19  5/101
# ...

# %% [markdown]
# # West Indian

# %%
df41=pd.read_csv(r"C:\Users\Gayan\Downloads\WI batting.csv")
df42=df41.drop(columns=['Span','NO','BF','0','4s','6s'])

# %%
df43=pd.read_csv(r"C:\Users\Gayan\Downloads\WI bowling.csv")
df44=df43.drop(columns=['Span','Mat','Inns','Overs','Mdns','Runs','Ct','St'])

# %%
df45=pd.merge(df42, df44, on='Player')
df45
# Out:
#            Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0     J Blackwood   12    23   709   104  30.82  53.63    1   4    1   1/16
# 1       NE Bonner    5     8   385  113*  55.00  38.19    1   2    1   1/16
# 2   KC Brathwaite   13    26   673   126  25.88  39.61    1   4    5   3/25
# 3        DM Bravo    4     8    79   23*  11.28  45.66    0   0    -      -
# 4      SSJ Brooks    7    14   311    68  22.21  42.14    0   3    -      -
# 5     JD Campbell   11    22   390    68  18.57  45.61    0   1    0      -
# 6        RL Chase    9    17   320    62  18.82  39.70    0   2   18  5/172
# 7    RRS Cornwall    7    12   181    73  18.10  66.54    0   2   22   5/74
# 8      ML Cummins    1     2    19   19*  19.00  28.35    0   0    0      -
# 9      J Da Silva    7    13   317    92  26.41  38.70    0   2    -      -
# 10     SO Dowrich    4     6   126    61  21.00  53.38    0   1    -      -
# ...

# %%
df_WI=df45.assign(Country = ['West Indian']*24)
df_WI
# Out:
#            Player  Mat  Inns  Runs    HS  Ave_x   SR_x  100  50 Wkts    BBI  \
# 0     J Blackwood   12    23   709   104  30.82  53.63    1   4    1   1/16
# 1       NE Bonner    5     8   385  113*  55.00  38.19    1   2    1   1/16
# 2   KC Brathwaite   13    26   673   126  25.88  39.61    1   4    5   3/25
# 3        DM Bravo    4     8    79   23*  11.28  45.66    0   0    -      -
# 4      SSJ Brooks    7    14   311    68  22.21  42.14    0   3    -      -
# 5     JD Campbell   11    22   390    68  18.57  45.61    0   1    0      -
# 6        RL Chase    9    17   320    62  18.82  39.70    0   2   18  5/172
# 7    RRS Cornwall    7    12   181    73  18.10  66.54    0   2   22   5/74
# 8      ML Cummins    1     2    19   19*  19.00  28.35    0   0    0      -
# 9      J Da Silva    7    13   317    92  26.41  38.70    0   2    -      -
# 10     SO Dowrich    4     6   126    61  21.00  53.38    0   1    -      -
# ...

# %% [markdown]
# # Combined data set

# %%
df_list = [df_AUS, df_BAN,df_ENG,df_IND,df_NZ,df_PAK,df_SF,df_SL,df_WI]
df_RWTC = pd.concat(df_list)
df_RWTC
# Out:
#          Player  Mat Inns Runs    HS  Ave_x   SR_x 100 50 Wkts    BBI    BBM  \
# 0   CT Bancroft    2    4   44    16     11  27.16   0  0    -      -      -
# 1      JA Burns    7   12  319    97     29   46.7   0  3    -      -      -
# 2    PJ Cummins   14   20  180    28  10.58  31.69   0  0   70   5/28   7/69
# 3       C Green    4    7  236    84  33.71  40.68   0  1    0      -      -
# 4     MS Harris    4    8  101    38  12.62  44.69   0  0    -      -      -
# ..          ...  ...  ...  ...   ...    ...    ...  .. ..  ...    ...    ...
# 19    KR Mayers    6   12  521  210*  47.36  62.62   1  2   10   3/24   6/52
# 20    S Moseley    2    4   28    12   7.00  26.66   0  0    -      -      -
# 21   KOA Powell    2    3   70    51  23.33  45.16   0  1    -      -      -
# 22    KAJ Roach   11   19  133    38   9.50   40.3   0  0   39   4/52   7/97
# 23  JA Warrican    2    3    8     4   2.66   25.8   0  0   10  4/133  7/190
#
#     Ave_y  Econ  SR_y  5 10      Country
# ...

# %% [markdown]
# # Reset Index Number

# %%
df_WTC1= df_RWTC.reset_index(drop=True)
df_WTC1
# Out:
#           Player  Mat Inns Runs    HS  Ave_x   SR_x 100 50 Wkts    BBI    BBM  \
# 0    CT Bancroft    2    4   44    16     11  27.16   0  0    -      -      -
# 1       JA Burns    7   12  319    97     29   46.7   0  3    -      -      -
# 2     PJ Cummins   14   20  180    28  10.58  31.69   0  0   70   5/28   7/69
# 3        C Green    4    7  236    84  33.71  40.68   0  1    0      -      -
# 4      MS Harris    4    8  101    38  12.62  44.69   0  0    -      -      -
# ..           ...  ...  ...  ...   ...    ...    ...  .. ..  ...    ...    ...
# 203    KR Mayers    6   12  521  210*  47.36  62.62   1  2   10   3/24   6/52
# 204    S Moseley    2    4   28    12   7.00  26.66   0  0    -      -      -
# 205   KOA Powell    2    3   70    51  23.33  45.16   0  1    -      -      -
# 206    KAJ Roach   11   19  133    38   9.50   40.3   0  0   39   4/52   7/97
# 207  JA Warrican    2    3    8     4   2.66   25.8   0  0   10  4/133  7/190
#
# ...

# %% [markdown]
# # Replace Missing Values from 0

# %%
df_WTC=df_WTC1.replace(to_replace ="-",value =0)
df_WTC
# Out:
#           Player  Mat Inns Runs    HS  Ave_x   SR_x 100 50 Wkts    BBI    BBM  \
# 0    CT Bancroft    2    4   44    16     11  27.16   0  0    0      0      0
# 1       JA Burns    7   12  319    97     29   46.7   0  3    0      0      0
# 2     PJ Cummins   14   20  180    28  10.58  31.69   0  0   70   5/28   7/69
# 3        C Green    4    7  236    84  33.71  40.68   0  1    0      0      0
# 4      MS Harris    4    8  101    38  12.62  44.69   0  0    0      0      0
# ..           ...  ...  ...  ...   ...    ...    ...  .. ..  ...    ...    ...
# 203    KR Mayers    6   12  521  210*  47.36  62.62   1  2   10   3/24   6/52
# 204    S Moseley    2    4   28    12   7.00  26.66   0  0    0      0      0
# 205   KOA Powell    2    3   70    51  23.33  45.16   0  1    0      0      0
# 206    KAJ Roach   11   19  133    38   9.50   40.3   0  0   39   4/52   7/97
# 207  JA Warrican    2    3    8     4   2.66   25.8   0  0   10  4/133  7/190
#
# ...

# %% [markdown]
# # Convert to Excel file

# %%
df_WTC.to_excel (r'C:\Users\Gayan\Downloads\WTC.xlsx', index = None, header=True)
